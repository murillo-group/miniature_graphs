# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
# Load dataframes
targets = pd.read_csv("../data/networks/giant_hamsterster/reductions/coarsening/test.csv")
targets
# Out:
#    alpha
# 0   0.05
# 1   0.15
# 2   0.25
# 3   0.35
# 4   0.45
# 5   0.55
# 6   0.65
# 7   0.75
# 8   0.85
# 9   0.95

# %%
metrics_df = pd.read_csv("../results/giant_hamsterster/coarsening/test/metrics.csv")

# %%
metrics_df = pd.read_csv("../results/giant_hamsterster/coarsening/test/metrics.csv")
degree_df = pd.read_csv("../results/giant_hamsterster/coarsening/test/distribution_degree.csv")
distance_df = pd.read_csv("../results/giant_hamsterster/coarsening/test/distribution_distance.csv")
qois_df = pd.read_csv("../results/giant_hamsterster/coarsening/test/qois/sir.csv",header=[0,1],index_col=0)
qois_df
# Out:
#   time-to-peak                                    peak                \
#           mean           std   min   max          mean           std
# 0       [13.6]  [3.66606056]  [10]  [23]  [0.48736842]  [0.01508792]
# 1         [9.]  [4.64758002]   [0]  [14]  [0.38417647]  [0.19201706]
# 2        [7.6]  [5.64269439]   [0]  [18]  [0.34966667]  [0.22870558]
# 3        [9.9]   [4.2296572]   [0]  [18]  [0.46476923]  [0.15536588]
# 4        [8.4]  [4.58693798]   [0]  [14]  [0.40962761]  [0.20489465]
# 5         [8.]  [2.82842712]   [0]  [10]  [0.45860155]  [0.15355016]
# 6        [8.5]  [3.52845575]   [0]  [15]  [0.43671429]  [0.14658013]
# 7        [8.7]  [4.05092582]   [0]  [17]      [0.4222]  [0.14231641]
# 8        [4.2]  [4.57820926]   [0]  [12]  [0.22566667]   [0.2264364]
# 9        [4.8]  [5.47357287]   [0]  [14]       [0.176]  [0.17872884]
#
#                                    size                                \
# ...
