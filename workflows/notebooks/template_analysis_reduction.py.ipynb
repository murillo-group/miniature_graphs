# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/mnt/home/martjor/.conda/envs/minigraphs_env/lib/python3.12/site-packages', '/mnt/ufs18/home-245/martjor/repos/dev_pt/workflows', '/mnt/ufs18/home-245/martjor/.conda/envs/minigraphs_env/bin', '/opt/software-current/2023.06/x86_64/amd/zen2/software/Python-bundle-PyPI/2023.06-GCCcore-12.3.0/lib/python3.11/site-packages', '/opt/software-current/2023.06/x86_64/amd/zen2/software/virtualenv/20.23.1-GCCcore-12.3.0/lib/python3.11/site-packages', '/opt/software-current/2023.06/x86_64/amd/zen2/software/cryptography/41.0.1-GCCcore-12.3.0/lib/python3.11/site-packages', '/opt/software-current/2023.06/x86_64/amd/zen2/software/cffi/1.15.1-GCCcore-12.3.0/lib/python3.11/site-packages', '/opt/software-current/2023.06/x86_64/amd/zen2/software/Python/3.11.3-GCCcore-12.3.0/easybuild/python', '/mnt/home/martjor/.conda/envs/minigraphs_env/lib/python3.12', '/mnt/home/martjor/.conda/envs/minigraphs_env/lib/python3.12/lib-dynload', '/mnt/home/martjor/.conda/envs/minigraphs_env/lib/python3.12/site-packages', '/mnt/ufs18/home-245/martjor/repos/dev_pt/src', '/mnt/home/martjor/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpvavpfqt0/file/mnt/ufs18/home-245/martjor/repos/dev_pt/workflows/notebooks', '/mnt/ufs18/home-245/martjor/repos/dev_pt/workflows/notebooks']);import pickle;from snakemake import script;script.snakemake = pickle.loads(b'\x80\x04\x95\x06\t\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c=results/giant_hamsterster/sparsification/params_reduction.csv\x94\x8c:results/giant_hamsterster/sparsification/graph_metrics.csv\x94\x8c@results/giant_hamsterster/sparsification/distribution_degree.csv\x94\x8cBresults/giant_hamsterster/sparsification/distribution_distance.csv\x94\x8c5results/giant_hamsterster/sparsification/qois_sir.csv\x94\x8c2data/networks/giant_hamsterster/graph_metrics.yaml\x94\x8c8data/networks/giant_hamsterster/distribution_degree.yaml\x94\x8c:data/networks/giant_hamsterster/distribution_distance.yaml\x94\x8c-data/networks/giant_hamsterster/qois_sir.yaml\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x07metrics\x94K\x05N\x86\x94\x8c\x08d_degree\x94K\x06N\x86\x94\x8c\nd_distance\x94K\x07N\x86\x94\x8c\x08qois_sir\x94K\x08N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh h\x06\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h sbh!h#)\x81\x94}\x94h&h!sbh\x16h\x0fh\x18h\x10h\x1ah\x11h\x1ch\x12ub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c=results/giant_hamsterster/sparsification/plots/metrics_01.png\x94\x8c=results/giant_hamsterster/sparsification/plots/metrics_02.png\x94\x8c:results/giant_hamsterster/sparsification/plots/moments.png\x94\x8c6results/giant_hamsterster/sparsification/plots/sir.png\x94\x8c:results/giant_hamsterster/sparsification/plots/degroot.png\x94e}\x94(h\x14}\x94h\x1e]\x94(h h!eh h#)\x81\x94}\x94h&h sbh!h#)\x81\x94}\x94h&h!sbub\x8c\r_params_store\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(\x8c\x11figure.autolayout\x94\x88\x8c\nfigure.dpi\x94M,\x01\x8c\x0flines.linewidth\x94G?\xe0\x00\x00\x00\x00\x00\x00\x8c\x0clines.marker\x94\x8c\x01o\x94\x8c\x10lines.markersize\x94K\x01\x8c\x10errorbar.capsize\x94K\x02\x8c\x0eaxes.labelsize\x94K\n\x8c\tfont.size\x94K\x07ua}\x94(h\x14}\x94\x8c\x02rc\x94K\x00N\x86\x94sh\x1e]\x94(h h!eh h#)\x81\x94}\x94h&h sbh!h#)\x81\x94}\x94h&h!sbhIh=ub\x8c\r_params_types\x94}\x94\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x11giant_hamsterster\x94\x8c\x0esparsification\x94e}\x94(h\x14}\x94(\x8c\x05graph\x94K\x00N\x86\x94\x8c\x06method\x94K\x01N\x86\x94uh\x1e]\x94(h h!eh h#)\x81\x94}\x94h&h sbh!h#)\x81\x94}\x94h&h!sb\x8c\x05graph\x94hV\x8c\x06method\x94hWub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x14}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x1e]\x94(h h!eh h#)\x81\x94}\x94h&h sbh!h#)\x81\x94}\x94h&h!sbhmK\x01hoK\x01hqhjub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94}\x94(h\x14}\x94h\x1e]\x94(h h!eh h#)\x81\x94}\x94h&h sbh!h#)\x81\x94}\x94h&h!sbub\x8c\x06config\x94}\x94(\x8c\x07rc_file\x94\x8c\x17notebooks/.matplotlibrc\x94\x8c\x07methods\x94}\x94(\x8c\x0esparsification\x94}\x94(\x8c\x08n_graphs\x94K\n\x8c\nparameters\x94}\x94\x8c\x07stretch\x94\x8c\x1910 ** np.linspace(1,2,20)\x94su\x8c\ncoarsening\x94}\x94(\x8c\x08n_graphs\x94K\x01\x8c\nparameters\x94}\x94\x8c\x05alpha\x94\x8c\x19np.linspace(0.05,0.95,20)\x94suu\x8c\x06models\x94}\x94\x8c\x03sir\x94}\x94(\x8c\x03tau\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x05gamma\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x07n_steps\x94M\xe8\x03\x8c\x08n_trials\x94K\x1eusu\x8c\x04rule\x94\x8c\x0eplot_reduction\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c</mnt/ufs18/home-245/martjor/repos/dev_pt/workflows/notebooks\x94ub.');del script;from snakemake.logging import logger;from snakemake.script import snakemake; logger.printshellcmds = False;import os; os.chdir(r'/mnt/ufs18/home-245/martjor/repos/dev_pt/workflows');
######## snakemake preamble end #########

# %%
# start coding here
import matplotlib.pyplot as plt 
import matplotlib 
import pandas as pd
import os
import yaml

def load_dict(file):
    with open(file,'r') as f:
        return yaml.safe_load(f)
    

# Update matplotlib rc params
for param, value in snakemake.params.rc.items():
    matplotlib.rcParams[param] = value
    
# Load dataframes
df_names = ["parameters",
            "graph_metrics",
            "distribution_degree",
            "distribution_distance",
            "qois_sir"]

dfs = {}
for name, file in zip(df_names, snakemake.input):
    if "qois" in name:
        header = [0,1]
    else:
        header = 0
        
    # Load Dataframe
    dfs[name] =  pd.read_csv(file,index_col=0,header=header)
    
    if name == "parameters":
        targets = dfs[name].iloc[:,0]
        names_parameters = dfs[name].columns
    elif "qois" in name:
        dfs[name] = dfs[name].groupby(targets).mean()
    else:
        dfs[name] = dfs[name].groupby(targets).describe(percentiles=[])

names = ["graph_metrics","distribution_degree","distribution_distance","sir"]
files = [snakemake.input.metrics,
         snakemake.input.d_degree,
         snakemake.input.d_distance,
         snakemake.input.qois_sir]
parent = {name: load_dict(file) for name, file in zip(names,files)}
parent['graph_metrics']

method = snakemake.wildcards.method

# %%
df = dfs["graph_metrics"]
x = df.index 
fig, axes = plt.subplots(2,1,figsize=(6,4))
# DATA
p = parent["graph_metrics"]

# PLOT
axes[0].errorbar(x,(p["n_nodes"]-df["n_nodes"]["mean"])/p["n_nodes"],yerr=(df["n_nodes"]["std"])/p["n_edges"]*3)
axes[1].errorbar(x,(p["n_edges"]-df["n_edges"]["mean"])/p["n_edges"],yerr=(df["n_edges"]["std"])/p["n_edges"]*3)

# FORMAT
axes[0].set_title("Fraction of nodes removed")
axes[0].set_xticks([])


axes[1].set_title("Fraction of edges removed")
axes[1].set_xlabel(names_parameters[0].capitalize())

for i, ax in enumerate(axes):
    if method == "sparsification":
        ax.set_xscale("log")
    
    if i != 1:
        ax.set_xticks([])
        
    ax.set_ylim([-0.1,1.1])
            
plt.savefig(snakemake.output[0])

# %%
df = dfs["graph_metrics"]
x = df.index 
metrics = ["density",
           "clustering",
           "assortativity",
           "connectivity"]

fig, axes = plt.subplots(len(metrics),1,figsize=(7.5,15))

for i, metric in enumerate(metrics):
    yerr = df[metric]["std"]*3
    axes[i].errorbar(x, df[metric]["mean"],yerr=yerr)
    axes[i].set_ylabel(metric.capitalize())
    axes[i].axhline(parent["graph_metrics"][metric],linestyle='--',color='r')
    
    if method == "sparsification":
        axes[i].set_xscale("log")
    
plt.tight_layout()
plt.savefig(snakemake.output[1])

# %%
fig, axes = plt.subplots(2,1,figsize=(8,6))

distribution = ["distribution_degree","distribution_distance"]
label = ["degree", "pairwise distance"]
for i, distribution in enumerate(distribution):
    axes[i].errorbar(x,dfs[distribution]["mean"]["mean"],yerr=dfs[distribution]["mean"]["std"]*3)
    axes[i].set_ylabel(f"Mean {label[i]}")
    axes[i].axhline(parent[distribution]["mean"],linestyle="--",color='r')
    
    if method == "sparsification":
        ax.set_xscale("log")
    
axes[1].set_xlabel(names_parameters[0].capitalize())
    
plt.tight_layout()
plt.savefig(snakemake.output[2])

# %%
fig, axes = plt.subplots(3,1,figsize=(9,9))

df = dfs["qois_sir"]
for i, metric in enumerate(df.columns.get_level_values(0).unique()):
    yerr = [df[metric]["mean"] - df[metric]["min"],
            df[metric]["max"] - df[metric]["mean"]]
    
    axes[i].errorbar(x,df[metric]["mean"],yerr=df[metric]["std"])
    axes[i].axhline(parent["sir"][metric]["mean"],linestyle='--',color='r')
    axes[i].set_ylabel(metric.capitalize())
    
    if method=="sparsification":
        ax.set_xscale("log")
        
plt.savefig(snakemake.output[3])
