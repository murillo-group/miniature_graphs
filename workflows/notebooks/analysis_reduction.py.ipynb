# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/mnt/home/martjor/.conda/envs/minigraphs_env/lib/python3.12/site-packages', '/mnt/ufs18/home-245/martjor/repos/dev_pt/workflows', '/mnt/ufs18/home-245/martjor/.conda/envs/minigraphs_env/bin', '/opt/software-current/2023.06/x86_64/amd/zen2/software/Python-bundle-PyPI/2023.06-GCCcore-12.3.0/lib/python3.11/site-packages', '/opt/software-current/2023.06/x86_64/amd/zen2/software/virtualenv/20.23.1-GCCcore-12.3.0/lib/python3.11/site-packages', '/opt/software-current/2023.06/x86_64/amd/zen2/software/cryptography/41.0.1-GCCcore-12.3.0/lib/python3.11/site-packages', '/opt/software-current/2023.06/x86_64/amd/zen2/software/cffi/1.15.1-GCCcore-12.3.0/lib/python3.11/site-packages', '/opt/software-current/2023.06/x86_64/amd/zen2/software/Python/3.11.3-GCCcore-12.3.0/easybuild/python', '/mnt/home/martjor/.conda/envs/minigraphs_env/lib/python3.12', '/mnt/home/martjor/.conda/envs/minigraphs_env/lib/python3.12/lib-dynload', '/mnt/home/martjor/.conda/envs/minigraphs_env/lib/python3.12/site-packages', '/mnt/ufs18/home-245/martjor/repos/dev_pt/src', '/mnt/home/martjor/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpjftj8sje/file/mnt/ufs18/home-245/martjor/repos/dev_pt/workflows/notebooks', '/mnt/ufs18/home-245/martjor/repos/dev_pt/workflows/notebooks']);import pickle;from snakemake import script;script.snakemake = pickle.loads(b'\x80\x04\x95\x92\x06\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c=results/giant_hamsterster/sparsification/graph_parameters.csv\x94\x8c:results/giant_hamsterster/sparsification/graph_metrics.csv\x94\x8cFresults/giant_hamsterster/sparsification/graph_distribution_degree.csv\x94\x8cHresults/giant_hamsterster/sparsification/graph_distribution_distance.csv\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\nparameters\x94K\x00N\x86\x94\x8c\x07metrics\x94K\x01N\x86\x94\x8c\x06degree\x94K\x02N\x86\x94\x8c\x08distance\x94K\x03N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x1bh\x06\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h\x1bsbh\x1ch\x1e)\x81\x94}\x94h!h\x1csbh\x11h\nh\x13h\x0bh\x15h\x0ch\x17h\rub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c:results/giant_hamsterster/sparsification/plots/targets.png\x94a}\x94(h\x0f}\x94h\x19]\x94(h\x1bh\x1ceh\x1bh\x1e)\x81\x94}\x94h!h\x1bsbh\x1ch\x1e)\x81\x94}\x94h!h\x1csbub\x8c\r_params_store\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0f}\x94h\x19]\x94(h\x1bh\x1ceh\x1bh\x1e)\x81\x94}\x94h!h\x1bsbh\x1ch\x1e)\x81\x94}\x94h!h\x1csbub\x8c\r_params_types\x94}\x94\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x11giant_hamsterster\x94\x8c\x0esparsification\x94e}\x94(h\x0f}\x94(\x8c\x05graph\x94K\x00N\x86\x94\x8c\x06method\x94K\x01N\x86\x94uh\x19]\x94(h\x1bh\x1ceh\x1bh\x1e)\x81\x94}\x94h!h\x1bsbh\x1ch\x1e)\x81\x94}\x94h!h\x1csb\x8c\x05graph\x94hA\x8c\x06method\x94hBub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x0f}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x19]\x94(h\x1bh\x1ceh\x1bh\x1e)\x81\x94}\x94h!h\x1bsbh\x1ch\x1e)\x81\x94}\x94h!h\x1csbhXK\x01hZK\x01h\\hUub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94}\x94(h\x0f}\x94h\x19]\x94(h\x1bh\x1ceh\x1bh\x1e)\x81\x94}\x94h!h\x1bsbh\x1ch\x1e)\x81\x94}\x94h!h\x1csbub\x8c\x06config\x94}\x94(\x8c\x08n_trials\x94K\n\x8c\ngraphs_dir\x94\x8c6/mnt/home/martjor/repos/dev_pt/workflows/data/networks\x94\x8c\x07test_id\x94\x8c\x04test\x94\x8c\x07methods\x94}\x94(\x8c\x0esparsification\x94}\x94(\x8c\x08n_graphs\x94K\x03\x8c\nparameters\x94}\x94\x8c\x07stretch\x94\x8c\x1910 ** np.linspace(1,2,10)\x94su\x8c\ncoarsening\x94}\x94(\x8c\x08n_graphs\x94K\x01\x8c\nparameters\x94}\x94\x8c\x05alpha\x94\x8c\x19np.linspace(0.05,0.95,10)\x94suu\x8c\x06models\x94}\x94\x8c\x03sir\x94}\x94(\x8c\x03tau\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x05gamma\x94G?\xb9\x99\x99\x99\x99\x99\x9a\x8c\x07n_steps\x94M\xe8\x03\x8c\x08n_trials\x94K\nusu\x8c\x04rule\x94\x8c\x0eplot_reduction\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c</mnt/ufs18/home-245/martjor/repos/dev_pt/workflows/notebooks\x94ub.');del script;from snakemake.logging import logger;from snakemake.script import snakemake; logger.printshellcmds = False;import os; os.chdir(r'/mnt/ufs18/home-245/martjor/repos/dev_pt/workflows');
######## snakemake preamble end #########

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
parameters=pd.read_csv(snakemake.input.parameters)
metrics=pd.read_csv(snakemake.input.metrics)

target = parameters['stretch']
parameters=parameters.groupby(target).describe()
metrics=metrics.groupby(target).describe()

# %%
fig, ax = plt.subplots()
ax.plot(metrics.index,metrics['density']['mean'])
