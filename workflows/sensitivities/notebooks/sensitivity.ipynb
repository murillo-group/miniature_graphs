# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

metric = "assortativity"
plt.rcParams["figure.autolayout"] = True
plt.rcParams["figure.dpi"] = 300
plt.rcParams["lines.linewidth"] = 0.5
plt.rcParams["lines.marker"] = 'o'
plt.rcParams["lines.markersize"] = 1
plt.rcParams["errorbar.capsize"] = 2
plt.rcParams["axes.labelsize"]=10
plt.rcParams["font.size"]=7

# %% [markdown]
# # Load Data

# %%
DIR = f"../results/{metric}/"

graphs_df = pd.read_csv(DIR + "graphs.csv", index_col=0)
graphs_group = graphs_df.groupby('target').describe()
graphs_group
# Out:
#           assortativity                                                        \
#                   count      mean       std       min       25%           50%
# target
# -0.950000           5.0 -0.941338  0.001128 -0.942729 -0.942300 -9.410147e-01
# -0.844444           5.0 -0.837141  0.003349 -0.843001 -0.836414 -8.358863e-01
# -0.738889           5.0 -0.732105  0.002279 -0.735445 -0.732344 -7.322563e-01
# -0.633333           5.0 -0.625660  0.002686 -0.630148 -0.626125 -6.244030e-01
# -0.527778           5.0 -0.523330  0.005928 -0.532334 -0.525986 -5.215738e-01
# -0.422222           5.0 -0.418913  0.005072 -0.425784 -0.422143 -4.175439e-01
# -0.316667           5.0 -0.313142  0.004822 -0.316959 -0.316514 -3.164863e-01
# -0.211111           5.0 -0.210954  0.000869 -0.211712 -0.211317 -2.111865e-01
# -0.105556           5.0 -0.105626  0.000159 -0.105792 -0.105692 -1.056780e-01
#  0.000000           5.0  0.000137  0.000333 -0.000113 -0.000050 -5.551115e-16
#  0.105556           5.0  0.105668  0.000276  0.105288  0.105470  1.058090e-01
#  0.211111           5.0  0.209827  0.003537  0.203525  0.210887  2.113817e-01
#  0.316667           5.0  0.311160  0.003361  0.308454  0.308543  3.107025e-01
#  0.422222           5.0  0.419714  0.007538  0.412470  0.415388  4.183767e-01
#  0.527778           5.0  0.522013  0.003477  0.518816  0.519608  5.208125e-01
#  0.633333           5.0  0.626103  0.002476  0.623899  0.624500  6.250759e-01
#  0.738889           5.0  0.730934  0.001098  0.729775  0.730276  7.304063e-01
#  0.844444           5.0  0.834896  0.000406  0.834571  0.834600  8.346783e-01
#  0.950000           5.0  0.940864  0.000633  0.940129  0.940422  9.407988e-01
#
#                               clustering            ...                      \
#                 75%       max      count      mean  ...       75%       max
# target                                              ...
# -0.950000 -0.940500 -0.940144        5.0  0.012667  ...  0.011000  0.026333
# -0.844444 -0.835874 -0.834528        5.0  0.012929  ...  0.015024  0.027000
# -0.738889 -0.731371 -0.729106        5.0  0.029881  ...  0.034960  0.035944
# -0.633333 -0.624035 -0.623590        5.0  0.019648  ...  0.023810  0.043833
# -0.527778 -0.518765 -0.517992        5.0  0.031940  ...  0.044310  0.049238
# -0.422222 -0.416163 -0.412929        5.0  0.029968  ...  0.036349  0.045310
# -0.316667 -0.308311 -0.307438        5.0  0.046136  ...  0.051206  0.052651
# -0.211111 -0.211095 -0.209458        5.0  0.042520  ...  0.050165  0.063310
# -0.105556 -0.105598 -0.105369        5.0  0.034185  ...  0.037476  0.041730
#  0.000000  0.000136  0.000710        5.0  0.034121  ...  0.044040  0.048325
#  0.105556  0.105830  0.105942        5.0  0.040708  ...  0.053135  0.062579
#  0.211111  0.211670  0.211671        5.0  0.035444  ...  0.038333  0.055841
#  0.316667  0.311396  0.316704        5.0  0.028610  ...  0.031952  0.039190
#  0.422222  0.420209  0.432127        5.0  0.030802  ...  0.036452  0.047913
#  0.527778  0.523445  0.527385        5.0  0.039017  ...  0.043000  0.045921
#  0.105556    22.466667  14.169502   6.6  38.8  0.283333  0.120300  0.122
#  0.211111    12.066667  12.487067   0.0  27.0  0.183333  0.175520  0.010
#  0.316667    24.666667  10.796897  11.4  37.4  0.277333  0.074955  0.180
#  0.422222    15.000000  11.644005   2.4  29.2  0.201333  0.151351  0.012
#  0.527778    15.733333   9.628793   4.6  27.0  0.174667  0.088010  0.062
#  0.633333    14.466667  14.085832   0.0  31.0  0.154667  0.123572  0.010
#  0.738889    17.200000   7.394591   8.2  25.8  0.187333  0.069212  0.096
#  0.844444    17.200000  10.228452   4.2  28.2  0.170667  0.089119  0.062
#  0.950000     9.400000   6.467355   1.4  16.4  0.100667  0.071150  0.016
#
#                       size
#              max      mean       std    min    max
# target
# -0.950000  0.290  0.484667  0.371688  0.010  0.822
# -0.844444  0.188  0.438667  0.153517  0.272  0.606
# -0.738889  0.340  0.590000  0.320561  0.194  0.894
# -0.633333  0.366  0.608000  0.343012  0.124  0.874
# -0.527778  0.320  0.617333  0.161730  0.488  0.834
# -0.422222  0.288  0.404000  0.240391  0.178  0.696
# -0.316667  0.364  0.518000  0.394552  0.020  0.874
# -0.211111  0.344  0.336000  0.387035  0.010  0.842
# -0.105556  0.328  0.508000  0.304158  0.176  0.828
#  0.000000  0.216  0.325333  0.273908  0.046  0.646
#  0.105556  0.398  0.666667  0.249783  0.316  0.870
#  0.211111  0.392  0.397333  0.391292  0.010  0.856
#  0.316667  0.356  0.714000  0.153973  0.498  0.840
#  0.422222  0.354  0.490667  0.374466  0.012  0.838
#  0.527778  0.262  0.478000  0.253234  0.164  0.726
#  0.633333  0.284  0.399333  0.339391  0.012  0.746
#  0.738889  0.256  0.475333  0.162950  0.250  0.616
#  0.844444  0.262  0.466667  0.242438  0.174  0.722
#  0.950000  0.178  0.236667  0.182460  0.018  0.418

# %% [markdown]
# # Analysis

# %%
fig, ax = plt.subplots(figsize=(3,3))

y = graphs_group[metric]['mean']
yerr = graphs_group[metric]['std'] * 3
ax.errorbar(graphs_group.index,y,yerr=yerr,capthick=0.5)
ax.set_xlabel('p')
ax.set_ylabel(metric.capitalize())
ax.set_title(f"{metric.capitalize()} as a function of generation parameter")

# Adjust scale for density
if metric == "density":
    ax.set_xscale('log')
    ax.set_yscale('log')

# %%
fig, axes = plt.subplots(1,2,figsize=(6,3))
fig.suptitle("Metrics as a function of target")

x = graphs_group.index 
other_metrics = list(graphs_group.columns.get_level_values(0).unique())
other_metrics.remove(metric)

for i, ax in enumerate(axes):
    y = graphs_group.loc[:,other_metrics[i]]['mean']
    yerr = graphs_group.loc[:,other_metrics[i]]['std']*3
    
    ax.errorbar(x,y,yerr=yerr,capthick=0.5)
    ax.set_ylabel(other_metrics[i].capitalize())
    ax.set_xlabel(metric.capitalize())
    
    if metric == "density":
        ax.set_xscale('log')
    
    if other_metrics[i] == "assortativity":
        ax.set_ylim([-1,1])
    else:
        ax.set_ylim([0,1])

# %%
fig, axes = plt.subplots(1,3,figsize=(9,3))
fig.suptitle("SIR dynamics as a function of target metric")

x = graphs_group.index
metrics = dynamics_group.columns.get_level_values(0).unique()
for i, ax in enumerate(axes):
    temp_df = dynamics_group.loc[:,metrics[i]]
    y = temp_df['mean']
    yerr = [y - temp_df['min'],temp_df['max'] - y]
    
    ax.errorbar(x,y,yerr)
    
    ax.set_xlabel(metric.capitalize())
    ax.set_ylabel(metrics[i].capitalize())
    if metric == "density":
        ax.set_xscale("log")
