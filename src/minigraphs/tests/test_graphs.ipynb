# %%
from importlib import reload
import networkx as nx 
from minigraphs import utils 
from minigraphs import graphs
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 200
m = 10
assortativity = lambda m: nx.degree_assortativity_coefficient(nx.barabasi_albert_graph(n,m))

y = np.zeros(n-1)

for i in range(1,n):
    measurement = 0
    
    for j in range(m):
        measurement += assortativity(i)
        
    y[i-1] = measurement/m

# %%
y_span = y[np.argmax(y):]
x = np.arange(y_span.shape[0])
p = np.polyfit(x,y_span,2)
plt.plot(x,y_span)

# %%
np.argmax(y)
# Out:
# 12
